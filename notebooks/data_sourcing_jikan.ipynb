# %%
import sys
sys.path.append('./../src')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import datetime
import time
import random
import re
from bs4 import BeautifulSoup
import requests
import web_scraping as ws
from importlib import reload
from jikanpy import Jikan
from copy import deepcopy

# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline
sns.set(color_codes=True)
plt.style.use('seaborn-colorblind')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)
pd.set_option('display.precision', 2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-5582751fdad1> in <module>
#      10 from bs4 import BeautifulSoup
#      11 import requests
# ---> 12 import web_scraping as ws
#      13 from importlib import reload
#      14 from jikanpy import Jikan
#
# ModuleNotFoundError: No module named 'web_scraping'

# %%
reload(ws)
# Out:
# <module 'web_scraping' from './../src/web_scraping.py'>

# %%
with open('../pickles/mal_ids_top_1000_anime.pkl', 'rb') as read_file:
    mal_ids_top_1000_anime = pickle.load(read_file)

# %%
with open('../container_pickles/animelist_data_100_TEST0.pkl', 'rb') as read_file:
    animelist_data_100_TEST0 = pickle.load(read_file)

# %%
with open('../rescraped_pickles/animelist_rescraped_100_870.pkl', 'rb') as read_file:
    animelist_rescraped_100_870 = pickle.load(read_file)

# %%
len(animelist_rescraped_100_870)
# Out:
# 13

# %%
animelist_rescraped_100_870
# Out:
# [{'user_id': 'Kvik',
#   'animelist_url': 'https://myanimelist.net/animelist/Kvik',
#   'animelist_titles': ['Boku no Hero Academia 3rd Season',
#    'Boruto: Naruto Next Generations',
#    'Code Geass: Hangyaku no Lelouch',
#    'Steins;Gate 0',
#    'Tokyo Ghoul:re',
#    'Akame ga Kill!',
#    'Akuma no Riddle',
#    'Akuma no Riddle: Shousha wa Dare? Nukiuchi Test',
#    'Angel Beats!',
#    'Another',
#    'Another: The Other - Inga',
#    'Ansatsu Kyoushitsu',
#    'Ansatsu Kyoushitsu 2nd Season',
#    'Black★Rock Shooter (OVA)',
#    'Black★Rock Shooter (TV)',
#    'Boku dake ga Inai Machi',
#    'Boku no Hero Academia',
#    'Boku no Hero Academia 2nd Season',
#    'Byousoku 5 Centimeter',
#    'Corpse Party: Missing Footage',
#    'Corpse Party: Tortured Souls - Bougyakusareta Tamashii no Jukyou',
#    'Danganronpa: Kibou no Gakuen to Zetsubou no Koukousei The Animation',
#    'Danshi Koukousei no Nichijou',
#    'Deadman Wonderland',
# ...

# %%
counter = 0
for animelist in animelist_data_100_TEST1:
    if animelist['animelist_titles'] == ['${ item.anime_title }']:
        counter += 1
counter
# Out:
# 0

# %%
list1 = [0, 1, 2]

# %%
list1[2:]
# Out:
# [2]
