# %%
import sys
sys.path.append('./../src')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import datetime
import time
import random
import re
from bs4 import BeautifulSoup
import requests
import web_scraping as ws
from importlib import reload
from jikanpy import Jikan
from copy import deepcopy

# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline
sns.set(color_codes=True)
plt.style.use('seaborn-colorblind')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)
pd.set_option('display.precision', 2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-5582751fdad1> in <module>
#      10 from bs4 import BeautifulSoup
#      11 import requests
# ---> 12 import web_scraping as ws
#      13 from importlib import reload
#      14 from jikanpy import Jikan
#
# ModuleNotFoundError: No module named 'web_scraping'

# %%
reload(ws)
# Out:
# <module 'web_scraping' from './../src/web_scraping.py'>

# %%
with open('../pickles/mal_ids_top_1000_anime.pkl', 'rb') as read_file:
    mal_ids_top_1000_anime = pickle.load(read_file)

# %%
with open('../container_pickles/animelist_data_100_TEST0.pkl', 'rb') as read_file:
    animelist_data_100_TEST0 = pickle.load(read_file)

# %%
with open('../rescraped_pickles/animelist_rescraped_100_62.pkl', 'rb') as read_file:
    animelist_rescraped_100_62 = pickle.load(read_file)

# %%
len(animelist_rescraped_100_62)
# Out:
# 100

# %%
animelist_rescraped_100_62
# Out:
# [{'user_id': 'Verienkeli',
#   'animelist_url': 'https://myanimelist.net/animelist/Verienkeli',
#   'animelist_titles': None,
#   'animelist_scores': None},
#  {'user_id': 'grande',
#   'animelist_url': 'https://myanimelist.net/animelist/grande',
#   'animelist_titles': None,
#   'animelist_scores': None},
#  {'user_id': 'Flame_cro',
#   'animelist_url': 'https://myanimelist.net/animelist/Flame_cro',
#   'animelist_titles': ['.hack//Sign',
#    'Afro Samurai',
#    'Afro Samurai: Resurrection',
#    'Ai Shimai 2: Futari no Kajitsu',
#    'Ai Shimai: Futari no Kajitsu',
#    'Akira',
#    'Ane Jiru The Animation: Shirakawa Sanshimai ni Omakase',
#    'Ane☆Haramix',
#    'Ani*Kuri15',
#    'Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.',
#    'Appleseed (Movie)',
#    'Aru Tabibito no Nikki',
#    'Aru Tabibito no Nikki Specials',
#    'Bastard!!: Ankoku no Hakaishin',
#    'Biohazard: Degeneration',
#    'Black★Rock Shooter (OVA)',
#    'Bounen no Xamdou',
# ...

# %%
counter = 0
for animelist in animelist_data_100_TEST1:
    if animelist['animelist_titles'] == ['${ item.anime_title }']:
        counter += 1
counter
# Out:
# 0

# %%
list1 = [0, 1, 2]

# %%
list1[2:]
# Out:
# [2]
